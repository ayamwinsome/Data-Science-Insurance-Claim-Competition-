# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv("C:\\Users\\WINSOME\\data-science-nigeria-insurance-claims-competition\\train.csv")
test  = pd.read_csv("C:\\Users\WINSOME\\data-science-nigeria-insurance-claims-competition\\test.csv")
sample  = pd.read_csv("C:\\Users\WINSOME\\data-science-nigeria-insurance-claims-competition\\sample_submission.csv")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer_ID                  700 non-null    object
#  1   months_as_customer           700 non-null    int64
#  2   age                          700 non-null    int64
#  3   insured_sex                  700 non-null    object
#  4   insured_education_level      700 non-null    object
#  5   insured_occupation           700 non-null    object
#  6   insured_hobbies              700 non-null    object
#  7   insured_relationship         700 non-null    object
#  8   capital-gains                700 non-null    int64
#  9   capital-loss                 700 non-null    int64
#  10  policy_number                700 non-null    int64
#  11  policy_bind_date             700 non-null    object
#  12  policy_state                 700 non-null    object
# ...

# %%
total_claim_amount_train = train.total_claim_amount
total_claim_amount_train
# Out:
# 0       14386.67
# 1       76440.00
# 2       79560.00
# 3      121680.00
# 4       80640.00
#          ...
# 695    106400.00
# 696    113733.33
# 697     78466.67
# 698     97866.67
# 699     38400.00
# Name: total_claim_amount, Length: 700, dtype: float64

# %%
df = pd.concat([train.drop(['total_claim_amount'], axis=1),test])
df
# Out:
#       Customer_ID  months_as_customer  age insured_sex  \
# 0    Customer_541                 239   41      FEMALE
# 1    Customer_440                 108   31        MALE
# 2    Customer_482                 116   30        MALE
# 3    Customer_422                   8   21        MALE
# 4    Customer_778                 161   38        MALE
# ..            ...                 ...  ...         ...
# 295  Customer_468                 225   37      FEMALE
# 296  Customer_935                 154   34      FEMALE
# 297  Customer_428                 167   36      FEMALE
# 298    Customer_7                 165   37        MALE
# 299  Customer_155                 375   50        MALE
#
#     insured_education_level insured_occupation insured_hobbies  \
# 0                        JD    farming-fishing       paintball
# 1                   Masters    protective-serv        yachting
# 2                        JD  handlers-cleaners            golf
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 299
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Customer_ID                  1000 non-null   object
#  1   months_as_customer           1000 non-null   int64
#  2   age                          1000 non-null   int64
#  3   insured_sex                  1000 non-null   object
#  4   insured_education_level      1000 non-null   object
#  5   insured_occupation           1000 non-null   object
#  6   insured_hobbies              1000 non-null   object
#  7   insured_relationship         1000 non-null   object
#  8   capital-gains                1000 non-null   int64
#  9   capital-loss                 1000 non-null   int64
#  10  policy_number                1000 non-null   int64
#  11  policy_bind_date             1000 non-null   object
#  12  policy_state                 1000 non-null   object
# ...

# %%
df.drop(['Customer_ID', 'insured_sex',
       'insured_education_level', 'insured_occupation', 'insured_hobbies',
       'insured_relationship','policy_bind_date', 'policy_state', 'policy_csl', 'incident_location','property_damage',
       'incident_date', 'incident_type', 'collision_type', 'incident_severity',
       'authorities_contacted', 'incident_state', 'incident_city',
       'police_report_available', 'auto_make', 'auto_model', 'auto_year',
       '_c39'], inplace=True,axis=1)

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'capital-gains', 'capital-loss',
#        'policy_number', 'policy_deductable', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'bodily_injuries',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'witnesses'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 299
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   capital-gains                1000 non-null   int64
#  3   capital-loss                 1000 non-null   int64
#  4   policy_number                1000 non-null   int64
#  5   policy_deductable            1000 non-null   int64
#  6   incident_hour_of_the_day     1000 non-null   int64
#  7   number_of_vehicles_involved  1000 non-null   int64
#  8   bodily_injuries              1000 non-null   int64
#  9   policy_annual_premium        1000 non-null   float64
#  10  umbrella_limit               1000 non-null   int64
#  11  insured_zip                  1000 non-null   int64
#  12  witnesses                    1000 non-null   int64
# ...

# %%
df.head()
# Out:
#    months_as_customer  age  capital-gains  capital-loss  policy_number  \
# 0                 239   41          51400         -6300         743092
# 1                 108   31              0             0         492224
# 2                 116   30              0        -35500         996253
# 3                   8   21              0             0         355085
# 4                 161   38          60200             0         192524
#
#    policy_deductable  incident_hour_of_the_day  number_of_vehicles_involved  \
# 0               1000                        22                            1
# 1               2000                        14                            1
# 2                500                         8                            3
# 3                500                        21                            1
# 4               2000                         0                            3
#
#    bodily_injuries  policy_annual_premium  umbrella_limit  insured_zip  \
# ...

# %%
df_train = df.iloc[:700]
df_test = df.iloc[700:]

# %%
X = df_train.values
test = df_test.values
y = total_claim_amount_train.values

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
import lightgbm as lgb #install this library using pip install lgbm if you don't have it 
from catboost import CatBoostRegressor #
# Out:
# array([68298.77634907, 85120.25904707, 85235.58158773, 80363.84250473,
#        63982.19460827, 78449.1857223 , 72047.50293743, 77322.72563817,
#        84681.35007367, 62179.4560914 , 57991.39810376, 89745.9562816 ,
#        67596.71726747, 71026.73737041, 53049.39116643, 58125.07021729,
#        85886.42758656, 83038.80969273, 79948.29407587, 73510.08283911,
#        70971.81235654, 57359.06542498, 77614.45644644, 58007.75468682,
#        67899.75077516, 91374.66791578, 73260.87093631, 69560.12068784,
#        82451.65287885, 54776.22532237, 53498.00536972, 87077.75192434,
#        58107.33225503, 58943.94046227, 94789.59502144, 74572.83762258,
#        83517.4014153 , 61540.20692534, 70364.28909883, 79264.99392931,
#        75191.94991958, 62425.7419961 , 60479.83424426, 77248.63706346,
#        76821.45835807, 61840.60613531, 84025.97276017, 61629.3170368 ,
#        68142.12896467, 58157.6390923 , 75359.2784764 , 55883.40246092,
# ...

# %%
sample =pd.read_csv("C:\\Users\WINSOME\\data-science-nigeria-insurance-claims-competition\\sample_submission.csv")

# %%
submission1={'Customer_ID'  : sample['Customer_ID'], 'total_claim_amount': predictions}

# %%
submission1 = pd.DataFrame(submission1)
submission1.head()
# Out:
#     Customer_ID  total_claim_amount
# 0  Customer_521        68298.776349
# 1  Customer_737        85120.259047
# 2  Customer_740        85235.581588
# 3  Customer_660        80363.842505
# 4  Customer_411        63982.194608

# %%
submission1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer_ID         300 non-null    object
#  1   total_claim_amount  300 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 4.8+ KB

# %%
submission1.to_csv('C:\\Users\\WINSOME\\insurance1.csv',index=False)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regressor = RandomForestRegressor(n_estimators = 100, random_state =0)

# %%
regressor.fit(X,y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
pred=regressor.predict(test)
pred
# Out:
# array([68232.2662, 71437.4664, 75359.8674, 84588.9338, 49908.8007,
#        79464.3996, 80348.9333, 77129.9997, 83407.8669, 38324.4011,
#        36718.6672, 70899.9999, 61732.8003, 84540.9334, 41603.734 ,
#        41709.7338, 79356.9325, 88693.7329, 86378.5337, 84577.2   ,
#        96932.7994, 33534.667 , 92646.4003, 32336.5329, 66985.4675,
#        89872.8   , 80020.7991, 61048.1338, 87228.5326, 29971.2006,
#        66065.1995, 83174.6674, 65530.5331, 67981.2001, 88838.1333,
#        71975.5998, 74342.5328, 45718.5335, 88488.3996, 73355.0657,
#        86855.3327, 79996.3998, 67743.466 , 86339.7327, 78073.3331,
#        46154.0001, 81735.8664, 51716.5335, 59552.2671, 55545.0676,
#        77115.1999, 16626.1332, 23329.3335, 82092.9332, 90092.2673,
#        70432.266 , 82206.6668, 86267.1991, 83689.0666, 82311.9995,
#        81519.4663, 36826.3997, 91453.733 , 55325.0666, 75206.5329,
#        79251.7335, 77321.466 , 80672.3996, 84192.1328, 75649.4655,
# ...

# %%
sample =pd.read_csv("C:\\Users\WINSOME\\data-science-nigeria-insurance-claims-competition\\sample_submission.csv")

# %%
submission1={'Customer_ID'  : sample['Customer_ID'], 'total_claim_amount': pred}

# %%
submission = pd.DataFrame(submission1)
submission.head()
# Out:
#     Customer_ID  total_claim_amount
# 0  Customer_521          68232.2662
# 1  Customer_737          71437.4664
# 2  Customer_740          75359.8674
# 3  Customer_660          84588.9338
# 4  Customer_411          49908.8007

# %%
submission.to_csv('C:\\Users\\WINSOME\\insurance.csv',index=False)

# %%
submission2={'Customer_ID'  : sample['Customer_ID'], 'total_claim_amount': blend}

# %%
sub = pd.DataFrame(submission2)
sub.head()
# Out:
#     Customer_ID  total_claim_amount
# 0  Customer_521        68265.521275
# 1  Customer_737        78278.862724
# 2  Customer_740        80297.724494
# 3  Customer_660        82476.388152
# 4  Customer_411        56945.497654

# %%
sub.to_csv('C:\\Users\\WINSOME\\insuranced.csv',index=False)

# %%
import lightgbm as lgb #install this library using pip install lgbm if you don't have it 
from catboost import CatBoostRegressor #

# %%
catm =CatBoostRegressor()

# %%
catm.fit(X,y)
# Out:
# Learning rate set to 0.036629
# 0:	learn: 34662.3404179	total: 110ms	remaining: 1m 49s
# 1:	learn: 34465.6373799	total: 113ms	remaining: 56.5s
# 2:	learn: 34278.2780978	total: 121ms	remaining: 40.2s
# 3:	learn: 34083.2396758	total: 128ms	remaining: 32s
# 4:	learn: 33880.3178882	total: 136ms	remaining: 27s
# 5:	learn: 33680.1022188	total: 143ms	remaining: 23.7s
# 6:	learn: 33465.4160032	total: 150ms	remaining: 21.3s
# 7:	learn: 33268.9216643	total: 157ms	remaining: 19.5s
# 8:	learn: 33045.7332891	total: 165ms	remaining: 18.1s
# 9:	learn: 32843.5225089	total: 171ms	remaining: 17s
# 10:	learn: 32676.8415169	total: 178ms	remaining: 16s
# 11:	learn: 32528.4445765	total: 193ms	remaining: 15.9s
# 12:	learn: 32361.4725997	total: 207ms	remaining: 15.7s
# 13:	learn: 32214.4636231	total: 235ms	remaining: 16.5s
# 14:	learn: 32065.4835144	total: 245ms	remaining: 16.1s
# 15:	learn: 31928.7795416	total: 252ms	remaining: 15.5s
# 16:	learn: 31840.9955097	total: 255ms	remaining: 14.8s
# ...

# %%
preds=catm.predict(test)
preds
# Out:
# array([ 64611.44579002,  70481.72814478,  74766.7524239 ,  94401.8262246 ,
#         44438.94908156,  78561.07361241,  82655.14191343,  69551.70929952,
#         83651.840047  ,  49049.63983207,  53283.07489979,  75744.31044798,
#         65209.49490141,  75991.46008608,  49437.11157799,  35911.1388535 ,
#         64457.58132085,  87949.32872054,  77745.36788106,  81708.85432674,
#        106751.67747178,  35170.32141891,  88330.73395634,  33641.82049121,
#         53080.74604506,  94629.19986174,  82743.65980395,  71068.6369169 ,
#         94049.0447282 ,  53324.51797318,  60136.77708315,  76794.4496548 ,
#         60277.0197544 ,  65482.16448706,  93995.33716597,  77847.4723475 ,
#         74951.86180709,  41499.00303468,  91325.27600249,  93233.10131542,
#         81982.59798452,  74432.07580794,  62410.36086567,  86057.79210209,
#         84585.0595662 ,  39039.89725996,  82902.0234768 ,  71780.28841554,
# ...

# %%
sample =pd.read_csv("C:\\Users\WINSOME\\data-science-nigeria-insurance-claims-competition\\sample_submission.csv")

# %%
submission3={'Customer_ID'  : sample['Customer_ID'], 'total_claim_amount': preds}

# %%
submission3 = pd.DataFrame(submission3)
submission3.head()
# Out:
#     Customer_ID  total_claim_amount
# 0  Customer_521        64611.445790
# 1  Customer_737        70481.728145
# 2  Customer_740        74766.752424
# 3  Customer_660        94401.826225
# 4  Customer_411        44438.949082

# %%
submission3.to_csv('C:\\Users\\WINSOME\\insuran.csv',index=False)

# %%
lgb =lgb.LGBMRegressor()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-129-ff539afb8e11> in <module>()
# ----> 1 lgb =lgb.LGBMRegressor()
#
# AttributeError: 'LGBMRegressor' object has no attribute 'LGBMRegressor'

# %%
lgb.fit(X,y)
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#        importance_type='split', learning_rate=0.05, max_depth=-1,
#        min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#        n_estimators=20, n_jobs=-1, num_leaves=31, objective=None,
#        random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#        subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
predict=lgb.predict(test)
predict
# Out:
# array([71865.77462004, 74925.4128189 , 87833.71991241, 83518.457657  ,
#        57064.8147575 , 73916.49094562, 70926.4170237 , 80187.24818778,
#        73519.99015458, 48469.0614008 , 47582.22756415, 74240.21454805,
#        60153.79142415, 77540.0838988 , 47884.33713489, 58241.18486209,
#        77247.35779334, 82199.94429512, 85447.56643487, 77513.82589271,
#        85543.54581228, 48116.94721446, 79425.42824589, 46495.38726082,
#        55123.19439273, 86814.6291375 , 79413.26130687, 74141.4519688 ,
#        85119.99093562, 53266.41486204, 64163.85514637, 74324.67468024,
#        74082.1256752 , 73650.50385559, 85611.08929263, 74683.74034638,
#        73460.25269427, 62069.13865817, 86835.6962063 , 79840.84378352,
#        81669.13396146, 72906.89325963, 72431.54180418, 79311.51395681,
#        84731.44620793, 49005.92092577, 78435.71133993, 46758.13897105,
#        71308.0007999 , 61500.97977206, 80187.24818778, 35656.11851722,
# ...

# %%
submission4={'Customer_ID'  : sample['Customer_ID'], 'total_claim_amount': predict}

# %%
submission4 = pd.DataFrame(submission4)
submission4.head()
# Out:
#     Customer_ID  total_claim_amount
# 0  Customer_521        71865.774620
# 1  Customer_737        74925.412819
# 2  Customer_740        87833.719912
# 3  Customer_660        83518.457657
# 4  Customer_411        57064.814758

# %%
submission4.to_csv('C:\\Users\\WINSOME\\insu.csv',index=False)

# %%
blend = ((0.4 * predict + 0.6 * preds) + (0.6 * predict + 0.4 * preds))/2

# %%
submission5={'Customer_ID'  : sample['Customer_ID'], 'total_claim_amount': blend}

# %%
submission5 = pd.DataFrame(submission5)
submission5.head()
# Out:
#     Customer_ID  total_claim_amount
# 0  Customer_521        68238.610205
# 1  Customer_737        72703.570482
# 2  Customer_740        81300.236168
# 3  Customer_660        88960.141941
# 4  Customer_411        50751.881920

# %%
submission5.to_csv('C:\\Users\\WINSOME\\finalsub.csv',index=False)
